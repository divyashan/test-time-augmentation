# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

sns.set_style('white')

# %%
cifar10_results = pd.read_csv('./results/cifar10/hflip_modified_five_crop_scale/val/cifar10_cnn_agg_fs')
sns.barplot(x='aug', y='top1', hue='agg', data=cifar10_results)
plt.ylim(83, 95)
plt.title("CIFAR-10")
#cifar10_results[cifar10_results['aug'] == 'orig']
# Out:
# Text(0.5, 1.0, 'CIFAR-10')

# %%
cifar100_results = pd.read_csv('./results/cifar100/hflip_modified_five_crop_scale/train/cifar100_cnn_agg_fs')
sns.barplot(x='aug', y='top1', hue='agg', data=cifar100_results)
plt.ylim(65, 80)
#plt.ylim(90, 100)
plt.title("CIFAR-100")
# Out:
# Text(0.5, 1.0, 'CIFAR-100')

# %%
stl10_results = pd.read_csv('./results/stl10/hflip_modified_five_crop_scale/val/stl10_cnn_agg_fs')
sns.barplot(x='aug', y='top1', hue='agg', data=stl10_results)
plt.ylim(75, 80)
plt.title("STL-10")
# Out:
# Text(0.5, 1.0, 'STL-10')

# %%
svhn_results = pd.read_csv('./results/svhn/hflip_modified_five_crop_scale/val/resnet20_agg_fs')
sns.barplot(x='aug', y='top1', hue='agg', data=svhn_results)
plt.ylim(95, 98)
plt.title("SVHN")
# Out:
# Text(0.5, 1.0, 'SVHN')

# %%
results = pd.read_csv("results/imnet/hflip_modified_five_crop_scale/val/inceptionv3_agg_fs")
sns.barplot(x='aug', y='top1', hue='agg', data=results)
#plt.ylim(68, 73)
#plt.ylim(74, 80)
#plt.ylim(70, 74)
#plt.ylim(55, 60)
plt.ylim(70, 76)
plt.title("ImageNet, InceptionV3")
# Out:
# Text(0.5, 1.0, 'ImageNet, InceptionV3')

# %%
model_name = 'MobileNetV2'
results = pd.read_csv("results/imnet/five_crop_hflip_scale/val/" + model_name + "_agg_fs")
sns.barplot(x='aug', y='top1', hue='agg', data=results)
if model_name == 'inceptionv3':
    plt.ylim(69, 74)
elif model_name == 'resnet18':
    plt.ylim(68, 73)
elif model_name == 'MobileNetV2':
    plt.ylim(76, 83)
elif model_name == 'resnet50':
    plt.ylim(75, 79)
plt.title("ImageNet, " + model_name)
# Out:
# Text(0.5, 1.0, 'ImageNet, MobileNetV2')

# %%
#birds200 results
model_name = 'resnet50'
results = pd.read_csv("results/birds200/five_crop_hflip_scale/val/" + model_name + "_agg_fs")
sns.barplot(x='aug', y='top1', hue='agg', data=results)
if model_name == 'inceptionv3':
    plt.ylim(69, 74)
elif model_name == 'resnet18':
    plt.ylim(76, 82)
elif model_name == 'MobileNetV2':
    plt.ylim(76, 82)
elif model_name == 'resnet50':
    plt.ylim(79, 83)
#plt.ylim(74, 80)
#plt.ylim(70, 74)
#plt.ylim(55, 60)
#plt.ylim(88, 95)
#plt.ylim(80, 100)
plt.title("Birds200, " + model_name)
# Out:
# Text(0.5, 1.0, 'Birds200, resnet50')

# %%
#flowers102 results
model_name = 'MobileNetV2'
results = pd.read_csv("results/flowers102/five_crop_hflip_scale/val/" + model_name + "_agg_fs")
sns.barplot(x='aug', y='top1', hue='agg', data=results)
if model_name == 'inceptionv3':
    plt.ylim(87, 92)
elif model_name == 'resnet18':
    plt.ylim(88, 92)
elif model_name == 'MobileNetV2':
    plt.ylim(89, 92)
elif model_name == 'resnet50':
    plt.ylim(90, 93)
#plt.ylim(74, 80)
#plt.ylim(70, 74)
#plt.ylim(55, 60)
#plt.ylim(88, 95)
#plt.ylim(80, 100)
plt.title("Flowers102, " + model_name)
# Out:
# Text(0.5, 1.0, 'Flowers102, MobileNetV2')

# %%
#flowers102 results
model_name = 'resnet18'
results = pd.read_csv("results/birds200/pil/val/" + model_name + "_agg_fs")
sns.barplot(x='aug', y='top1', hue='agg', data=results)
if model_name == 'inceptionv3':
    plt.ylim(69, 74)
elif model_name == 'resnet18':
    plt.ylim(71, 79)
elif model_name == 'MobileNetV2':
    plt.ylim(76, 83)
elif model_name == 'resnet50':
    plt.ylim(90, 93)
#plt.ylim(74, 80)
#plt.ylim(70, 74)
#plt.ylim(55, 60)
#plt.ylim(88, 95)
#plt.ylim(80, 100)
plt.title("Birds200, " + model_name)
# Out:
# ------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-13-f961967e6718> in <module>
#       1 #flowers102 results
#       2 model_name = 'MobileNetV2'
# ----> 3 results = pd.read_csv("results/birds200/pil/val/" + model_name + "_agg_fs")
#       4 sns.barplot(x='aug', y='top1', hue='agg', data=results)
#       5 if model_name == 'inceptionv3':
#
# ...
